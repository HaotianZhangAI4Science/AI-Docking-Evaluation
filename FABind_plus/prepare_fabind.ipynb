# %%
import os
import csv
import shutil
from rdkit import Chem

def copy_pdb_files(source_folder, destination_folder):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    for root, dirs, files in os.walk(source_folder):
        for file in files:
            if file.endswith('_protein.pdb'):
                source_path = os.path.join(root, file)
                destination_path = os.path.join(destination_folder, file)
                destination_path = destination_path.replace('_protein', '')
                shutil.copy2(source_path, destination_path)
                print(f"Copied: {file.replace('_protein', '')}")
    print(f"All PDB files have been copied to {destination_folder}")

def copy_ligand_files(source_folder, destination_folder):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    for root, dirs, files in os.walk(source_folder):
        for file in files:
            if file.endswith('_ligand.sdf') or file.endswith('_ligand.mol2'):
                source_path = os.path.join(root, file)
                destination_dir = os.path.join(destination_folder,source_path.split('/')[-2])
                if not os.path.exists(destination_dir):
                    os.makedirs(destination_dir)
                destination_path = os.path.join(destination_dir, file)
                shutil.copy2(source_path, destination_path)
                print(f"Copied: {file}")
            else:
                pass
    print(f"All SDF/MOL2 files have been copied to {destination_folder}")

def generate_csv(input_folder, output_file):
    with open(output_file, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(['Cleaned_SMILES', 'pdb_id', 'ligand_id'])
        for pdb_id in os.listdir(input_folder):
            subfolder_path = os.path.join(input_folder, pdb_id)
            if os.path.isdir(subfolder_path):
                ligand_file = os.path.join(subfolder_path, f'{pdb_id}_ligand.sdf')
                if os.path.exists(ligand_file):
                    mol = Chem.SDMolSupplier(ligand_file)[0] 
                    if mol is not None:
                        smiles = Chem.MolToSmiles(mol)
                        csvwriter.writerow([smiles, pdb_id, pdb_id])
                    else:
                        print(f"Warning: Could not read molecule from {ligand_file}")
                else:
                    print(f"Warning: ligand.sdf not found in {subfolder_path}")
    print(f"CSV file has been generated: {output_file}")

# eg
source_folder = '/mnt/data/posebusters/posebusters_benchmark_set'           # original set
destination_folder_pdb = '/mnt/data/posebusters_fabind/pdb_files'           # ouput pdb_files
destination_folder_ligand = '/mnt/data/posebusters_fabind/gt_mol_files'     # output gt_mol_files
output_csv_file = '/mnt/data/posebusters_fabind/ligands.csv'                # output csvfile 

copy_ligand_files(source_folder, destination_folder_ligand)
copy_pdb_files(source_folder, destination_folder_pdb)
generate_csv(destination_folder_ligand,output_csv_file)
# Out:
# Copied: 6TW5_9M2_ligand.sdf
# Copied: 6TW5_9M2_ligand.mol2
# Copied: 8E77_ULP_ligand.mol2
# Copied: 8E77_ULP_ligand.sdf
# Copied: 7U3J_L6U_ligand.sdf
# Copied: 7U3J_L6U_ligand.mol2
# Copied: 7M3H_YPV_ligand.sdf
# Copied: 7M3H_YPV_ligand.mol2
# Copied: 8AEM_LVF_ligand.sdf
# Copied: 8AEM_LVF_ligand.mol2
# Copied: 7JNB_A2G_ligand.sdf
# Copied: 7JNB_A2G_ligand.mol2
# Copied: 7AKL_RK5_ligand.sdf
# Copied: 7AKL_RK5_ligand.mol2
# Copied: 7OKF_VH5_ligand.sdf
# Copied: 7OKF_VH5_ligand.mol2
# Copied: 7BCP_GCO_ligand.sdf
# Copied: 7BCP_GCO_ligand.mol2
# Copied: 7WY1_D0L_ligand.sdf
# Copied: 7WY1_D0L_ligand.mol2
# Copied: 7Q27_8KC_ligand.sdf
# Copied: 7Q27_8KC_ligand.mol2
# Copied: 8AIE_M7L_ligand.sdf
# Copied: 8AIE_M7L_ligand.mol2
# Copied: 6YYO_Q1K_ligand.sdf
# Copied: 6YYO_Q1K_ligand.mol2
# Copied: 7NB4_U6Q_ligand.mol2
# Copied: 7NB4_U6Q_ligand.sdf
# Copied: 7NGW_UAW_ligand.sdf
# Copied: 7NGW_UAW_ligand.mol2
# Copied: 8H0M_2EH_ligand.mol2
# Copied: 8H0M_2EH_ligand.sdf
# Copied: 8EX2_Q2Q_ligand.sdf
# Copied: 8EX2_Q2Q_ligand.mol2
# Copied: 7UXS_OJC_ligand.mol2
# Copied: 7UXS_OJC_ligand.sdf
# Copied: 7MGY_ZD1_ligand.sdf
# Copied: 7MGY_ZD1_ligand.mol2
# Copied: 8DKO_TFB_ligand.sdf
# Copied: 8DKO_TFB_ligand.mol2
# Copied: 7CL8_TES_ligand.sdf
# Copied: 7CL8_TES_ligand.mol2
# Copied: 7T0U_E3I_ligand.mol2
# Copied: 7T0U_E3I_ligand.sdf
# Copied: 7PIH_7QW_ligand.sdf
# Copied: 7PIH_7QW_ligand.mol2
# Copied: 7ELT_TYM_ligand.sdf
# Copied: 7ELT_TYM_ligand.mol2
# Copied: 7ZU2_DHT_ligand.sdf
# Copied: 7ZU2_DHT_ligand.mol2
# Copied: 7ZOC_T8E_ligand.mol2
# Copied: 7ZOC_T8E_ligand.sdf
# Copied: 7N4N_0BK_ligand.mol2
# Copied: 7N4N_0BK_ligand.sdf
# Copied: 7SZA_DUI_ligand.sdf
# Copied: 7SZA_DUI_ligand.mol2
# Copied: 7W06_ITN_ligand.sdf
# Copied: 7W06_ITN_ligand.mol2
# Copied: 7UMW_NAD_ligand.mol2
# Copied: 7UMW_NAD_ligand.sdf
# Copied: 7NTG_F6R_ligand.mol2
# Copied: 7NTG_F6R_ligand.sdf
# Copied: 7DQL_4CL_ligand.mol2
# Copied: 7DQL_4CL_ligand.sdf
# Copied: 7ECR_SIN_ligand.mol2
# Copied: 7ECR_SIN_ligand.sdf
# Copied: 6ZPB_3D1_ligand.sdf
# Copied: 6ZPB_3D1_ligand.mol2
# Copied: 7X9K_8OG_ligand.sdf
# Copied: 7X9K_8OG_ligand.mol2
# Copied: 7SCW_GSP_ligand.sdf
# Copied: 7SCW_GSP_ligand.mol2
# Copied: 7D6O_MTE_ligand.mol2
# Copied: 7D6O_MTE_ligand.sdf
# Copied: 7B2C_TP7_ligand.mol2
# Copied: 7B2C_TP7_ligand.sdf
# Copied: 7BKA_4JC_ligand.mol2
# Copied: 7BKA_4JC_ligand.sdf
# Copied: 7RKW_5TV_ligand.sdf
# Copied: 7RKW_5TV_ligand.mol2
# Copied: 7E2S_BLA_ligand.mol2
# Copied: 7E2S_BLA_ligand.sdf
# Copied: 7NU0_DCL_ligand.mol2
# Copied: 7NU0_DCL_ligand.sdf
# Copied: 7WKL_CAQ_ligand.sdf
# Copied: 7WKL_CAQ_ligand.mol2
# Copied: 8D39_QDB_ligand.mol2
# Copied: 8D39_QDB_ligand.sdf
# Copied: 7SIU_9ID_ligand.sdf
# Copied: 7SIU_9ID_ligand.mol2
# Copied: 8BN6_R53_ligand.sdf
# Copied: 8BN6_R53_ligand.mol2
# Copied: 7LJN_GTP_ligand.sdf
# Copied: 7LJN_GTP_ligand.mol2
# Copied: 7QTA_URI_ligand.mol2
# Copied: 7QTA_URI_ligand.sdf
# Copied: 7P2I_MFU_ligand.mol2
# Copied: 7P2I_MFU_ligand.sdf
# Copied: 7ZZB_KGX_ligand.mol2
# Copied: 7ZZB_KGX_ligand.sdf
# Copied: 8HFN_XGC_ligand.sdf
# Copied: 8HFN_XGC_ligand.mol2
# Copied: 7JUD_MMA_ligand.mol2
# Copied: 7JUD_MMA_ligand.sdf
# Copied: 8C7Y_TXV_ligand.mol2
# Copied: 8C7Y_TXV_ligand.sdf
# Copied: 7L6D_BMF_ligand.sdf
# Copied: 7L6D_BMF_ligand.mol2
# Copied: 7QE4_NGA_ligand.mol2
# Copied: 7QE4_NGA_ligand.sdf
# Copied: 6ZXQ_IMO_ligand.mol2
# Copied: 6ZXQ_IMO_ligand.sdf
# Copied: 6ZAE_ACV_ligand.sdf
# Copied: 6ZAE_ACV_ligand.mol2
# Copied: 7T3E_SLB_ligand.mol2
# Copied: 7T3E_SLB_ligand.sdf
# Copied: 7XFA_D9J_ligand.sdf
# Copied: 7XFA_D9J_ligand.mol2
# Copied: 7XBV_APC_ligand.sdf
# Copied: 7XBV_APC_ligand.mol2
# Copied: 7UMV_NUU_ligand.mol2
# Copied: 7UMV_NUU_ligand.sdf
# Copied: 7LT0_ONJ_ligand.sdf
# Copied: 7LT0_ONJ_ligand.mol2
# Copied: 7L5F_XNG_ligand.mol2
# Copied: 7L5F_XNG_ligand.sdf
# Copied: 8C3N_ADP_ligand.mol2
# Copied: 8C3N_ADP_ligand.sdf
# Copied: 7TUO_KL9_ligand.sdf
# Copied: 7TUO_KL9_ligand.mol2
# Copied: 7WUY_76N_ligand.sdf
# Copied: 7WUY_76N_ligand.mol2
# Copied: 7R59_I5F_ligand.sdf
# Copied: 7R59_I5F_ligand.mol2
# Copied: 7ZHP_IQY_ligand.mol2
# Copied: 7ZHP_IQY_ligand.sdf
# Copied: 8AQL_PLG_ligand.sdf
# Copied: 8AQL_PLG_ligand.mol2
# Copied: 7KP6_WTP_ligand.mol2
# Copied: 7KP6_WTP_ligand.sdf
# Copied: 6XM9_V55_ligand.sdf
# Copied: 6XM9_V55_ligand.mol2
# Copied: 7AA0_R6B_ligand.sdf
# Copied: 7AA0_R6B_ligand.mol2
# Copied: 7T3F_EM0_ligand.sdf
# Copied: 7T3F_EM0_ligand.mol2
# Copied: 6TW7_NZB_ligand.mol2
# Copied: 6TW7_NZB_ligand.sdf
# Copied: 7THI_PGA_ligand.sdf
# Copied: 7THI_PGA_ligand.mol2
# Copied: 5SD5_HWI_ligand.mol2
# Copied: 5SD5_HWI_ligand.sdf
# Copied: 7P4J_5JK_ligand.sdf
# Copied: 7P4J_5JK_ligand.mol2
# Copied: 6YQW_82I_ligand.sdf
# Copied: 6YQW_82I_ligand.mol2
# Copied: 7ZF0_DHR_ligand.sdf
# Copied: 7ZF0_DHR_ligand.mol2
# Copied: 5S8I_2LY_ligand.sdf
# Copied: 5S8I_2LY_ligand.mol2
# Copied: 7V8Z_5YH_ligand.sdf
# Copied: 7V8Z_5YH_ligand.mol2
# Copied: 7MWU_ZPM_ligand.mol2
# Copied: 7MWU_ZPM_ligand.sdf
# Copied: 7NSW_HC4_ligand.mol2
# Copied: 7NSW_HC4_ligand.sdf
# Copied: 6WTN_RXT_ligand.sdf
# Copied: 6WTN_RXT_ligand.mol2
# Copied: 8HO0_3ZI_ligand.mol2
# Copied: 8HO0_3ZI_ligand.sdf
# Copied: 6XG5_TOP_ligand.mol2
# Copied: 6XG5_TOP_ligand.sdf
# Copied: 8FAV_4Y5_ligand.mol2
# Copied: 8FAV_4Y5_ligand.sdf
# Copied: 7PL1_SFG_ligand.mol2
# Copied: 7PL1_SFG_ligand.sdf
# Copied: 8SLG_G5A_ligand.mol2
# Copied: 8SLG_G5A_ligand.sdf
# Copied: 7X5N_5M5_ligand.sdf
# Copied: 7X5N_5M5_ligand.mol2
# Copied: 7CIJ_G0C_ligand.mol2
# Copied: 7CIJ_G0C_ligand.sdf
# Copied: 7RNI_60I_ligand.mol2
# Copied: 7RNI_60I_ligand.sdf
# Copied: 7O0N_CDP_ligand.mol2
# Copied: 7O0N_CDP_ligand.sdf
# Copied: 8G43_ZU6_ligand.sdf
# Copied: 8G43_ZU6_ligand.mol2
# Copied: 6ZC3_JOR_ligand.sdf
# Copied: 6ZC3_JOR_ligand.mol2
# Copied: 6ZX3_QRZ_ligand.sdf
# Copied: 6ZX3_QRZ_ligand.mol2
# Copied: 7ROR_69X_ligand.sdf
# Copied: 7ROR_69X_ligand.mol2
# Copied: 7USH_82V_ligand.mol2
# Copied: 7USH_82V_ligand.sdf
# Copied: 8EXL_799_ligand.sdf
# Copied: 8EXL_799_ligand.mol2
# Copied: 7B94_ANP_ligand.sdf
# Copied: 7B94_ANP_ligand.mol2
# Copied: 5SB2_1K2_ligand.sdf
# Copied: 5SB2_1K2_ligand.mol2
# Copied: 7ZDY_6MJ_ligand.mol2
# Copied: 7ZDY_6MJ_ligand.sdf
# Copied: 7DIN_MPO_ligand.sdf
# Copied: 7DIN_MPO_ligand.mol2
# Copied: 7TBU_S3P_ligand.mol2
# Copied: 7TBU_S3P_ligand.sdf
# Copied: 7OZ9_NGK_ligand.sdf
# Copied: 7OZ9_NGK_ligand.mol2
# Copied: 7NA4_1I9_ligand.mol2
# Copied: 7NA4_1I9_ligand.sdf
# Copied: 7BHX_TO5_ligand.mol2
# Copied: 7BHX_TO5_ligand.sdf
# Copied: 8G0V_YHT_ligand.sdf
# Copied: 8G0V_YHT_ligand.mol2
# Copied: 7JHQ_VAJ_ligand.mol2
# Copied: 7JHQ_VAJ_ligand.sdf
# Copied: 7JGW_V9S_ligand.mol2
# Copied: 7JGW_V9S_ligand.sdf
# Copied: 8BTI_RFO_ligand.mol2
# Copied: 8BTI_RFO_ligand.sdf
# Copied: 7K41_VUA_ligand.mol2
# Copied: 7K41_VUA_ligand.sdf
# Copied: 7OKC_VFE_ligand.mol2
# Copied: 7OKC_VFE_ligand.sdf
# Copied: 7M41_YQG_ligand.mol2
# Copied: 7M41_YQG_ligand.sdf
# Copied: 7EBG_J0L_ligand.sdf
# Copied: 7EBG_J0L_ligand.mol2
# Copied: 7P1M_4IU_ligand.sdf
# Copied: 7P1M_4IU_ligand.mol2
# Copied: 7F8T_FAD_ligand.sdf
# Copied: 7F8T_FAD_ligand.mol2
# Copied: 7QGP_DJ8_ligand.sdf
# Copied: 7QGP_DJ8_ligand.mol2
# Copied: 7L81_UD4_ligand.mol2
# Copied: 7L81_UD4_ligand.sdf
# Copied: 8D19_GSH_ligand.sdf
# Copied: 8D19_GSH_ligand.mol2
# Copied: 7BJJ_TVW_ligand.sdf
# Copied: 7BJJ_TVW_ligand.mol2
# Copied: 7SSM_B7L_ligand.mol2
# Copied: 7SSM_B7L_ligand.sdf
# Copied: 6YQV_8K2_ligand.mol2
# Copied: 6YQV_8K2_ligand.sdf
# Copied: 7NR8_UOE_ligand.sdf
# Copied: 7NR8_UOE_ligand.mol2
# Copied: 7NUT_GLP_ligand.mol2
# Copied: 7NUT_GLP_ligand.sdf
# Copied: 8CI0_8EL_ligand.mol2
# Copied: 8CI0_8EL_ligand.sdf
# Copied: 7ZYS_KNR_ligand.sdf
# Copied: 7ZYS_KNR_ligand.mol2
# Copied: 7P4V_DAT_ligand.mol2
# Copied: 7P4V_DAT_ligand.sdf
# Copied: 8F8E_XJI_ligand.mol2
# Copied: 8F8E_XJI_ligand.sdf
# Copied: 6Y7L_QMG_ligand.sdf
# Copied: 6Y7L_QMG_ligand.mol2
# Copied: 6YMS_OZH_ligand.mol2
# Copied: 6YMS_OZH_ligand.sdf
# Copied: 7L00_XCJ_ligand.mol2
# Copied: 7L00_XCJ_ligand.sdf
# Copied: 7EN7_J79_ligand.mol2
# Copied: 7EN7_J79_ligand.sdf
# Copied: 7U0U_FK5_ligand.mol2
# Copied: 7U0U_FK5_ligand.sdf
# Copied: 7NF3_4LU_ligand.sdf
# Copied: 7NF3_4LU_ligand.mol2
# Copied: 7UEY_N0R_ligand.sdf
# Copied: 7UEY_N0R_ligand.mol2
# Copied: 7WPW_F15_ligand.sdf
# Copied: 7WPW_F15_ligand.mol2
# Copied: 7KQU_YOF_ligand.mol2
# Copied: 7KQU_YOF_ligand.sdf
# Copied: 7OFK_VCH_ligand.sdf
# Copied: 7OFK_VCH_ligand.mol2
# Copied: 7OLI_8HG_ligand.sdf
# Copied: 7OLI_8HG_ligand.mol2
# Copied: 7BNH_BEZ_ligand.mol2
# Copied: 7BNH_BEZ_ligand.sdf
# Copied: 6M2B_EZO_ligand.sdf
# Copied: 6M2B_EZO_ligand.mol2
# Copied: 7W6F_8I6_ligand.sdf
# Copied: 7W6F_8I6_ligand.mol2
# Copied: 7R6J_2I7_ligand.sdf
# Copied: 7R6J_2I7_ligand.mol2
# Copied: 7WQQ_5Z6_ligand.mol2
# Copied: 7WQQ_5Z6_ligand.sdf
# Copied: 8ACL_LQL_ligand.mol2
# Copied: 8ACL_LQL_ligand.sdf
# Copied: 7Q19_DSM_ligand.mol2
# Copied: 7Q19_DSM_ligand.sdf
# Copied: 6ZK5_IMH_ligand.mol2
# Copied: 6ZK5_IMH_ligand.sdf
# Copied: 7QF4_RBF_ligand.mol2
# Copied: 7QF4_RBF_ligand.sdf
# Copied: 7SGV_L30_ligand.sdf
# Copied: 7SGV_L30_ligand.mol2
# Copied: 7PRM_81I_ligand.mol2
# Copied: 7PRM_81I_ligand.sdf
# Copied: 7UJ5_DGL_ligand.mol2
# Copied: 7UJ5_DGL_ligand.sdf
# Copied: 7KC5_BJZ_ligand.sdf
# Copied: 7KC5_BJZ_ligand.mol2
# Copied: 7TWC_CXS_ligand.sdf
# Copied: 7TWC_CXS_ligand.mol2
# Copied: 7T2I_E9F_ligand.sdf
# Copied: 7T2I_E9F_ligand.mol2
# Copied: 5SIS_JSM_ligand.sdf
# Copied: 5SIS_JSM_ligand.mol2
# Copied: 7MRH_ZMJ_ligand.mol2
# Copied: 7MRH_ZMJ_ligand.sdf
# Copied: 6ZR8_QOZ_ligand.sdf
# Copied: 6ZR8_QOZ_ligand.mol2
# Copied: 7PGX_FMN_ligand.mol2
# Copied: 7PGX_FMN_ligand.sdf
# Copied: 7PK0_BYC_ligand.sdf
# Copied: 7PK0_BYC_ligand.mol2
# Copied: 7RWS_4UR_ligand.mol2
# Copied: 7RWS_4UR_ligand.sdf
# Copied: 7JR8_VH7_ligand.mol2
# Copied: 7JR8_VH7_ligand.sdf
# Copied: 8CNH_V6U_ligand.mol2
# Copied: 8CNH_V6U_ligand.sdf
# Copied: 7ODX_DGP_ligand.mol2
# Copied: 7ODX_DGP_ligand.sdf
# Copied: 6YSP_PAL_ligand.mol2
# Copied: 6YSP_PAL_ligand.sdf
# Copied: 7ZCC_OGA_ligand.sdf
# Copied: 7ZCC_OGA_ligand.mol2
# Copied: 7LCU_XTA_ligand.mol2
# Copied: 7LCU_XTA_ligand.sdf
# Copied: 7L03_F9F_ligand.sdf
# Copied: 7L03_F9F_ligand.mol2
# Copied: 7UJF_R3V_ligand.mol2
# Copied: 7UJF_R3V_ligand.sdf
# Copied: 7TXP_0FX_ligand.mol2
# Copied: 7TXP_0FX_ligand.sdf
# Copied: 7ZXZ_K9R_ligand.mol2
# Copied: 7ZXZ_K9R_ligand.sdf
# Copied: 7RPZ_6IC_ligand.mol2
# Copied: 7RPZ_6IC_ligand.sdf
# Copied: 7TYP_KUR_ligand.mol2
# Copied: 7TYP_KUR_ligand.sdf
# Copied: 8DZT_G4P_ligand.sdf
# Copied: 8DZT_G4P_ligand.mol2
# Copied: 7A9E_R4W_ligand.sdf
# Copied: 7A9E_R4W_ligand.mol2
# Copied: 7RH8_UTP_ligand.sdf
# Copied: 7RH8_UTP_ligand.mol2
# Copied: 7ROU_66I_ligand.sdf
# Copied: 7ROU_66I_ligand.mol2
# Copied: 7OPG_06N_ligand.sdf
# Copied: 7OPG_06N_ligand.mol2
# Copied: 7V3S_5I9_ligand.mol2
# Copied: 7V3S_5I9_ligand.sdf
# Copied: 7OCB_V88_ligand.sdf
# Copied: 7OCB_V88_ligand.mol2
# Copied: 8AJX_FUM_ligand.sdf
# Copied: 8AJX_FUM_ligand.mol2
# Copied: 7PA4_C_ligand.sdf
# Copied: 7PA4_C_ligand.mol2
# Copied: 7S45_ACO_ligand.mol2
# Copied: 7S45_ACO_ligand.sdf
# Copied: 7E4L_MDN_ligand.mol2
# Copied: 7E4L_MDN_ligand.sdf
# Copied: 7BMI_U4B_ligand.mol2
# Copied: 7BMI_U4B_ligand.sdf
# Copied: 7R9N_F97_ligand.mol2
# Copied: 7R9N_F97_ligand.sdf
# Copied: 8BOM_QU6_ligand.mol2
# Copied: 8BOM_QU6_ligand.sdf
# Copied: 7REE_4LY_ligand.sdf
# Copied: 7REE_4LY_ligand.mol2
# Copied: 8FV9_80J_ligand.sdf
# Copied: 8FV9_80J_ligand.mol2
# Copied: 6X8D_ARA_ligand.sdf
# Copied: 6X8D_ARA_ligand.mol2
# Copied: 7KLX_WOV_ligand.sdf
# Copied: 7KLX_WOV_ligand.mol2
# Copied: 7P5T_5YG_ligand.mol2
# Copied: 7P5T_5YG_ligand.sdf
# Copied: 7QK0_EBL_ligand.mol2
# Copied: 7QK0_EBL_ligand.sdf
# Copied: 7CUO_PHB_ligand.sdf
# Copied: 7CUO_PHB_ligand.mol2
# Copied: 8GFD_ZHR_ligand.mol2
# Copied: 8GFD_ZHR_ligand.sdf
# Copied: 7A9H_TPP_ligand.sdf
# Copied: 7A9H_TPP_ligand.mol2
# Copied: 6YR2_T1C_ligand.sdf
# Copied: 6YR2_T1C_ligand.mol2
# Copied: 7MS7_ZQ1_ligand.mol2
# Copied: 7MS7_ZQ1_ligand.sdf
# Copied: 8C5D_GTB_ligand.mol2
# Copied: 8C5D_GTB_ligand.sdf
# Copied: 7N6F_0I1_ligand.sdf
# Copied: 7N6F_0I1_ligand.mol2
# Copied: 8AUH_L9I_ligand.sdf
# Copied: 8AUH_L9I_ligand.mol2
# Copied: 7JMV_4NC_ligand.mol2
# Copied: 7JMV_4NC_ligand.sdf
# Copied: 7MFP_Z7P_ligand.sdf
# Copied: 7MFP_Z7P_ligand.mol2
# Copied: 7Z2O_IAJ_ligand.mol2
# Copied: 7Z2O_IAJ_ligand.sdf
# Copied: 7JY3_VUD_ligand.sdf
# Copied: 7JY3_VUD_ligand.mol2
# Copied: 6XUM_30L_ligand.sdf
# Copied: 6XUM_30L_ligand.mol2
# Copied: 7QHG_T3B_ligand.sdf
# Copied: 7QHG_T3B_ligand.mol2
# Copied: 7LZQ_YJV_ligand.sdf
# Copied: 7LZQ_YJV_ligand.mol2
# Copied: 8AP0_PRP_ligand.sdf
# Copied: 8AP0_PRP_ligand.mol2
# Copied: 7LEV_0JO_ligand.sdf
# Copied: 7LEV_0JO_ligand.mol2
# Copied: 7SNE_9XR_ligand.mol2
# Copied: 7SNE_9XR_ligand.sdf
# Copied: 8FO5_Y4U_ligand.mol2
# Copied: 8FO5_Y4U_ligand.sdf
# Copied: 7VBU_6I4_ligand.sdf
# Copied: 7VBU_6I4_ligand.mol2
# Copied: 7BLA_WCS_ligand.mol2
# Copied: 7BLA_WCS_ligand.sdf
# Copied: 7D9L_GSF_ligand.mol2
# Copied: 7D9L_GSF_ligand.sdf
# Copied: 7XJN_NSD_ligand.sdf
# Copied: 7XJN_NSD_ligand.mol2
# Copied: 8EAB_VN2_ligand.mol2
# Copied: 8EAB_VN2_ligand.sdf
# Copied: 8AY3_OE3_ligand.sdf
# Copied: 8AY3_OE3_ligand.mol2
# Copied: 7Q2B_M6H_ligand.mol2
# Copied: 7Q2B_M6H_ligand.sdf
# Copied: 7P2W_4QR_ligand.mol2
# Copied: 7P2W_4QR_ligand.sdf
# Copied: 6XAF_GDP_ligand.mol2
# Copied: 6XAF_GDP_ligand.sdf
# Copied: 7MYU_ZR7_ligand.mol2
# Copied: 7MYU_ZR7_ligand.sdf
# Copied: 7TXK_LW8_ligand.mol2
# Copied: 7TXK_LW8_ligand.sdf
# Copied: 7BA0_T5H_ligand.sdf
# Copied: 7BA0_T5H_ligand.mol2
# Copied: 7MZS_GLA_ligand.mol2
# Copied: 7MZS_GLA_ligand.sdf
# Copied: 7V3N_AKG_ligand.sdf
# Copied: 7V3N_AKG_ligand.mol2
# Copied: 6Z2C_Q5E_ligand.sdf
# Copied: 6Z2C_Q5E_ligand.mol2
# Copied: 6Z14_Q4Z_ligand.mol2
# Copied: 6Z14_Q4Z_ligand.sdf
# Copied: 7NFB_GEN_ligand.sdf
# Copied: 7NFB_GEN_ligand.mol2
# Copied: 7LB3_XXS_ligand.mol2
# Copied: 7LB3_XXS_ligand.sdf
# Copied: 7T0D_FPP_ligand.mol2
# Copied: 7T0D_FPP_ligand.sdf
# Copied: 7KM8_WPD_ligand.sdf
# Copied: 7KM8_WPD_ligand.mol2
# Copied: 7OSO_0V1_ligand.mol2
# Copied: 7OSO_0V1_ligand.sdf
# Copied: 7PUV_84Z_ligand.mol2
# Copied: 7PUV_84Z_ligand.sdf
# Copied: 7NF0_BYN_ligand.mol2
# Copied: 7NF0_BYN_ligand.sdf
# Copied: 7KB1_WBJ_ligand.mol2
# Copied: 7KB1_WBJ_ligand.sdf
# Copied: 7CD9_FVR_ligand.sdf
# Copied: 7CD9_FVR_ligand.mol2
# Copied: 7C0U_FGO_ligand.sdf
# Copied: 7C0U_FGO_ligand.mol2
# Copied: 7CTM_BDP_ligand.sdf
# Copied: 7CTM_BDP_ligand.mol2
# Copied: 7XI7_4RI_ligand.mol2
# Copied: 7XI7_4RI_ligand.sdf
# Copied: 7DKT_GLF_ligand.mol2
# Copied: 7DKT_GLF_ligand.sdf
# Copied: 7NML_I7B_ligand.mol2
# Copied: 7NML_I7B_ligand.sdf
# Copied: 7MGT_ZD4_ligand.sdf
# Copied: 7MGT_ZD4_ligand.mol2
# Copied: 7ZL5_IWE_ligand.mol2
# Copied: 7ZL5_IWE_ligand.sdf
# Copied: 7UTW_NAI_ligand.sdf
# Copied: 7UTW_NAI_ligand.mol2
# Copied: 7WCF_ACP_ligand.mol2
# Copied: 7WCF_ACP_ligand.sdf
# Copied: 7FT9_4MB_ligand.mol2
# Copied: 7FT9_4MB_ligand.sdf
# Copied: 7N7B_T3F_ligand.sdf
# Copied: 7N7B_T3F_ligand.mol2
# Copied: 7Q25_8J9_ligand.sdf
# Copied: 7Q25_8J9_ligand.mol2
# Copied: 7SUC_COM_ligand.mol2
# Copied: 7SUC_COM_ligand.sdf
# Copied: 7OZC_G6S_ligand.mol2
# Copied: 7OZC_G6S_ligand.sdf
# Copied: 7JXX_VP7_ligand.sdf
# Copied: 7JXX_VP7_ligand.mol2
# Copied: 7P4C_5OV_ligand.sdf
# Copied: 7P4C_5OV_ligand.mol2
# Copied: 7F51_BA7_ligand.sdf
# Copied: 7F51_BA7_ligand.mol2
# Copied: 7WJB_BGC_ligand.mol2
# Copied: 7WJB_BGC_ligand.sdf
# Copied: 8BRO_R7E_ligand.mol2
# Copied: 8BRO_R7E_ligand.sdf
# Copied: 7MOI_HPS_ligand.mol2
# Copied: 7MOI_HPS_ligand.sdf
# Copied: 7TSF_H4B_ligand.mol2
# Copied: 7TSF_H4B_ligand.sdf
# Copied: 7ULC_56B_ligand.mol2
# Copied: 7ULC_56B_ligand.sdf
# Copied: 6W59_SZD_ligand.sdf
# Copied: 6W59_SZD_ligand.mol2
# Copied: 8FLV_ZB9_ligand.sdf
# Copied: 8FLV_ZB9_ligand.mol2
# Copied: 6Z5Z_BDF_ligand.sdf
# Copied: 6Z5Z_BDF_ligand.mol2
# Copied: 7D0P_1VU_ligand.sdf
# Copied: 7D0P_1VU_ligand.mol2
# Copied: 7UF2_5SP_ligand.mol2
# Copied: 7UF2_5SP_ligand.sdf
# Copied: 7JG0_GAR_ligand.sdf
# Copied: 7JG0_GAR_ligand.mol2
# Copied: 7C8Q_DSG_ligand.mol2
# Copied: 7C8Q_DSG_ligand.sdf
# Copied: 7UQ3_O2U_ligand.mol2
# Copied: 7UQ3_O2U_ligand.sdf
# Copied: 7NR6_UO8_ligand.sdf
# Copied: 7NR6_UO8_ligand.mol2
# Copied: 7VKZ_NOJ_ligand.mol2
# Copied: 7VKZ_NOJ_ligand.sdf
# Copied: 7PT3_3KK_ligand.mol2
# Copied: 7PT3_3KK_ligand.sdf
# Copied: 7TS6_KMI_ligand.sdf
# Copied: 7TS6_KMI_ligand.mol2
# Copied: 8EYE_X4I_ligand.mol2
# Copied: 8EYE_X4I_ligand.sdf
# Copied: 7FHA_ADX_ligand.mol2
# Copied: 7FHA_ADX_ligand.sdf
# Copied: 7K0V_VQP_ligand.sdf
# Copied: 7K0V_VQP_ligand.mol2
# Copied: 6YDY_K73_ligand.mol2
# Copied: 6YDY_K73_ligand.sdf
# Copied: 8BPL_CP_ligand.mol2
# Copied: 8BPL_CP_ligand.sdf
# Copied: 8ERS_WQO_ligand.sdf
# Copied: 8ERS_WQO_ligand.mol2
# Copied: 7XG5_PLP_ligand.mol2
# Copied: 7XG5_PLP_ligand.sdf
# Copied: 7ORW_7WA_ligand.mol2
# Copied: 7ORW_7WA_ligand.sdf
# Copied: 6Z1C_7EY_ligand.sdf
# Copied: 6Z1C_7EY_ligand.mol2
# Copied: 6Z0R_Q4H_ligand.mol2
# Copied: 6Z0R_Q4H_ligand.sdf
# Copied: 7RUI_7QZ_ligand.mol2
# Copied: 7RUI_7QZ_ligand.sdf
# Copied: 7NXO_UU8_ligand.sdf
# Copied: 7NXO_UU8_ligand.mol2
# Copied: 7F5D_EUO_ligand.mol2
# Copied: 7F5D_EUO_ligand.sdf
# Copied: 7VQ9_ISY_ligand.sdf
# Copied: 7VQ9_ISY_ligand.mol2
# Copied: 8A1H_DLZ_ligand.sdf
# Copied: 8A1H_DLZ_ligand.mol2
# Copied: 7OFF_VCB_ligand.mol2
# Copied: 7OFF_VCB_ligand.sdf
# Copied: 7S9H_7PP_ligand.sdf
# Copied: 7S9H_7PP_ligand.mol2
# Copied: 7AFX_R9K_ligand.mol2
# Copied: 7AFX_R9K_ligand.sdf
# Copied: 7VC5_9SF_ligand.mol2
# Copied: 7VC5_9SF_ligand.sdf
# Copied: 7LMO_NYO_ligand.mol2
# Copied: 7LMO_NYO_ligand.sdf
# Copied: 7MEU_MGP_ligand.sdf
# Copied: 7MEU_MGP_ligand.mol2
# Copied: 7R3D_APR_ligand.sdf
# Copied: 7R3D_APR_ligand.mol2
# Copied: 7UYB_OK0_ligand.mol2
# Copied: 7UYB_OK0_ligand.sdf
# Copied: 7M6K_YRJ_ligand.sdf
# Copied: 7M6K_YRJ_ligand.mol2
# Copied: 6YJA_2BA_ligand.sdf
# Copied: 6YJA_2BA_ligand.mol2
# Copied: 7VB8_STL_ligand.sdf
# Copied: 7VB8_STL_ligand.mol2
# Copied: 7OLT_58J_ligand.sdf
# Copied: 7OLT_58J_ligand.mol2
# Copied: 7PRI_7TI_ligand.mol2
# Copied: 7PRI_7TI_ligand.sdf
# Copied: 7D5C_GV6_ligand.mol2
# Copied: 7D5C_GV6_ligand.sdf
# Copied: 7ODY_DGI_ligand.sdf
# Copied: 7ODY_DGI_ligand.mol2
# Copied: 7ZZW_KKW_ligand.sdf
# Copied: 7ZZW_KKW_ligand.mol2
# Copied: 7C3U_AZG_ligand.mol2
# Copied: 7C3U_AZG_ligand.sdf
# Copied: 7UP3_NZ0_ligand.sdf
# Copied: 7UP3_NZ0_ligand.mol2
# Copied: 7R7R_AWJ_ligand.mol2
# Copied: 7R7R_AWJ_ligand.sdf
# Copied: 7NLK_UHK_ligand.sdf
# Copied: 7NLK_UHK_ligand.mol2
# Copied: 7DUA_HJ0_ligand.sdf
# Copied: 7DUA_HJ0_ligand.mol2
# Copied: 8AAU_LH0_ligand.sdf
# Copied: 8AAU_LH0_ligand.mol2
# Copied: 7C6P_SQH_ligand.mol2
# Copied: 7C6P_SQH_ligand.sdf
# Copied: 7N7H_CTP_ligand.mol2
# Copied: 7N7H_CTP_ligand.sdf
# Copied: 7L7C_XQ1_ligand.sdf
# Copied: 7L7C_XQ1_ligand.mol2
# Copied: 7LOE_Y84_ligand.sdf
# Copied: 7LOE_Y84_ligand.mol2
# Copied: 8AEU_M0L_ligand.mol2
# Copied: 8AEU_M0L_ligand.sdf
# Copied: 7T1D_E7K_ligand.mol2
# Copied: 7T1D_E7K_ligand.sdf
# Copied: 8DSC_NCA_ligand.sdf
# Copied: 8DSC_NCA_ligand.mol2
# Copied: 7VWF_K55_ligand.sdf
# Copied: 7VWF_K55_ligand.mol2
# Copied: 7XPO_UPG_ligand.sdf
# Copied: 7XPO_UPG_ligand.mol2
# Copied: 6T88_MWQ_ligand.mol2
# Copied: 6T88_MWQ_ligand.sdf
# Copied: 7BTT_F8R_ligand.sdf
# Copied: 7BTT_F8R_ligand.mol2
# Copied: 8CSD_C5P_ligand.mol2
# Copied: 8CSD_C5P_ligand.sdf
# Copied: 7MWN_WI5_ligand.sdf
# Copied: 7MWN_WI5_ligand.mol2
# Copied: 7XQZ_FPF_ligand.mol2
# Copied: 7XQZ_FPF_ligand.sdf
# Copied: 7SFO_98L_ligand.sdf
# Copied: 7SFO_98L_ligand.mol2
# Copied: 6XCT_478_ligand.sdf
# Copied: 6XCT_478_ligand.mol2
# Copied: 7RZL_NPO_ligand.mol2
# Copied: 7RZL_NPO_ligand.sdf
# Copied: 7OMX_CNA_ligand.mol2
# Copied: 7OMX_CNA_ligand.sdf
# Copied: 7Q5I_I0F_ligand.sdf
# Copied: 7Q5I_I0F_ligand.mol2
# Copied: 7UAS_MBU_ligand.mol2
# Copied: 7UAS_MBU_ligand.sdf
# Copied: 7ED2_A3P_ligand.sdf
# Copied: 7ED2_A3P_ligand.mol2
# Copied: 7D8Q_GZF_ligand.sdf
# Copied: 7D8Q_GZF_ligand.mol2
# Copied: 7WN5_JGL_ligand.sdf
# Copied: 7WN5_JGL_ligand.mol2
# Copied: 8DHG_T78_ligand.sdf
# Copied: 8DHG_T78_ligand.mol2
# Copied: 7M31_TDR_ligand.mol2
# Copied: 7M31_TDR_ligand.sdf
# Copied: 7MSR_DCA_ligand.sdf
# Copied: 7MSR_DCA_ligand.mol2
# Copied: 7KZ9_XN7_ligand.sdf
# Copied: 7KZ9_XN7_ligand.mol2
# Copied: 7A1P_QW2_ligand.mol2
# Copied: 7A1P_QW2_ligand.sdf
# Copied: 8C5M_MTA_ligand.mol2
# Copied: 8C5M_MTA_ligand.sdf
# Copied: 7BJ6_TVK_ligand.mol2
# Copied: 7BJ6_TVK_ligand.sdf
# Copied: 5SAK_ZRY_ligand.mol2
# Copied: 5SAK_ZRY_ligand.sdf
# Copied: 6Z4N_Q7B_ligand.mol2
# Copied: 6Z4N_Q7B_ligand.sdf
# Copied: 7Z1Q_NIO_ligand.sdf
# Copied: 7Z1Q_NIO_ligand.mol2
# Copied: 7QSW_CAP_ligand.mol2
# Copied: 7QSW_CAP_ligand.sdf
# Copied: 8CGC_LMR_ligand.sdf
# Copied: 8CGC_LMR_ligand.mol2
# Copied: 8FLN_Y7W_ligand.sdf
# Copied: 8FLN_Y7W_ligand.mol2
# Copied: 7SDD_4IP_ligand.mol2
# Copied: 7SDD_4IP_ligand.sdf
# Copied: 8DP2_UMA_ligand.mol2
# Copied: 8DP2_UMA_ligand.sdf
# Copied: 7TM6_GPJ_ligand.sdf
# Copied: 7TM6_GPJ_ligand.mol2
# Copied: 8D5D_5DK_ligand.mol2
# Copied: 8D5D_5DK_ligand.sdf
# Copied: 7XEK_9YX_ligand.mol2
# Copied: 7XEK_9YX_ligand.sdf
# Copied: 6ZT2_QPK_ligand.mol2
# Copied: 6ZT2_QPK_ligand.sdf
# Copied: 7VJT_7IJ_ligand.mol2
# Copied: 7VJT_7IJ_ligand.sdf
# Copied: 7FRX_O88_ligand.mol2
# Copied: 7FRX_O88_ligand.sdf
# Copied: 7UAW_MF6_ligand.sdf
# Copied: 7UAW_MF6_ligand.mol2
# Copied: 7WUX_6OI_ligand.sdf
# Copied: 7WUX_6OI_ligand.mol2
# Copied: 7Z7F_IF3_ligand.sdf
# Copied: 7Z7F_IF3_ligand.mol2
# Copied: 7V14_ORU_ligand.mol2
# Copied: 7V14_ORU_ligand.sdf
# Copied: 7POM_7VZ_ligand.mol2
# Copied: 7POM_7VZ_ligand.sdf
# Copied: 7SED_8VD_ligand.sdf
# Copied: 7SED_8VD_ligand.mol2
# Copied: 7OP9_06K_ligand.mol2
# Copied: 7OP9_06K_ligand.sdf
# Copied: 7RSV_7IQ_ligand.mol2
# Copied: 7RSV_7IQ_ligand.sdf
# Copied: 7TOM_5AD_ligand.mol2
# Copied: 7TOM_5AD_ligand.sdf
# Copied: 6XHT_V2V_ligand.sdf
# Copied: 6XHT_V2V_ligand.mol2
# Copied: 7W05_GMP_ligand.mol2
# Copied: 7W05_GMP_ligand.sdf
# Copied: 8F4J_PHO_ligand.mol2
# Copied: 8F4J_PHO_ligand.sdf
# Copied: 7O1T_5X8_ligand.sdf
# Copied: 7O1T_5X8_ligand.mol2
# Copied: 8AIJ_M9I_ligand.mol2
# Copied: 8AIJ_M9I_ligand.sdf
# Copied: 7NLV_UJE_ligand.mol2
# Copied: 7NLV_UJE_ligand.sdf
# Copied: 6XBO_5MC_ligand.sdf
# Copied: 6XBO_5MC_ligand.mol2
# Copied: 7N4W_P4V_ligand.sdf
# Copied: 7N4W_P4V_ligand.mol2
# Copied: 7UJ4_OQ4_ligand.mol2
# Copied: 7UJ4_OQ4_ligand.sdf
# Copied: 7OMJ_GCP_ligand.sdf
# Copied: 7OMJ_GCP_ligand.mol2
# Copied: 7V43_C4O_ligand.mol2
# Copied: 7V43_C4O_ligand.sdf
# Copied: 7KRU_ATP_ligand.sdf
# Copied: 7KRU_ATP_ligand.mol2
# Copied: 7T9O_GEI_ligand.sdf
# Copied: 7T9O_GEI_ligand.mol2
# Copied: 7QPP_VDX_ligand.mol2
# Copied: 7QPP_VDX_ligand.sdf
# Copied: 7MY1_IPE_ligand.mol2
# Copied: 7MY1_IPE_ligand.sdf
# Copied: 7KFO_IAC_ligand.sdf
# Copied: 7KFO_IAC_ligand.mol2
# Copied: 7VYJ_CA0_ligand.mol2
# Copied: 7VYJ_CA0_ligand.sdf
# Copied: 7QFM_AY3_ligand.sdf
# Copied: 7QFM_AY3_ligand.mol2
# Copied: 7CNS_PMV_ligand.sdf
# Copied: 7CNS_PMV_ligand.mol2
# Copied: 7NP6_UK8_ligand.sdf
# Copied: 7NP6_UK8_ligand.mol2
# Copied: 7XRL_FWK_ligand.mol2
# Copied: 7XRL_FWK_ligand.sdf
# Copied: 8G6P_API_ligand.sdf
# Copied: 8G6P_API_ligand.mol2
# Copied: 7XIJ_EJ3_ligand.mol2
# Copied: 7XIJ_EJ3_ligand.sdf
# Copied: 8EAD_UY0_ligand.mol2
# Copied: 8EAD_UY0_ligand.sdf
# Copied: 7RC3_SAH_ligand.sdf
# Copied: 7RC3_SAH_ligand.mol2
# Copied: 7QHL_D5P_ligand.mol2
# Copied: 7QHL_D5P_ligand.sdf
# Copied: 7AS1_21G_ligand.sdf
# Copied: 7AS1_21G_ligand.mol2
# Copied: 7EPV_FDA_ligand.mol2
# Copied: 7EPV_FDA_ligand.sdf
# Copied: 7AN5_RDH_ligand.mol2
# Copied: 7AN5_RDH_ligand.sdf
# Copied: 7FB7_8NF_ligand.sdf
# Copied: 7FB7_8NF_ligand.mol2
# Copied: 7OU8_1XI_ligand.mol2
# Copied: 7OU8_1XI_ligand.sdf
# Copied: 7P1F_KFN_ligand.mol2
# Copied: 7P1F_KFN_ligand.sdf
# Copied: 7LOU_IFM_ligand.sdf
# Copied: 7LOU_IFM_ligand.mol2
# Copied: 7BLG_GAL_ligand.mol2
# Copied: 7BLG_GAL_ligand.sdf
# Copied: 7ZTL_BCN_ligand.sdf
# Copied: 7ZTL_BCN_ligand.mol2
# Copied: 7ES1_UDP_ligand.mol2
# Copied: 7ES1_UDP_ligand.sdf
# Copied: 7MAE_XUS_ligand.mol2
# Copied: 7MAE_XUS_ligand.sdf
# Copied: 7OEO_V9Z_ligand.sdf
# Copied: 7OEO_V9Z_ligand.mol2
# Copied: 8B8H_OJQ_ligand.sdf
# Copied: 8B8H_OJQ_ligand.mol2
# Copied: 7AMC_73B_ligand.mol2
# Copied: 7AMC_73B_ligand.sdf
# Copied: 7RWO_7WN_ligand.mol2
# Copied: 7RWO_7WN_ligand.sdf
# Copied: 7TB0_UD1_ligand.mol2
# Copied: 7TB0_UD1_ligand.sdf
# Copied: 6ZCY_QF8_ligand.sdf
# Copied: 6ZCY_QF8_ligand.mol2
# Copied: 7MMH_ZJY_ligand.sdf
# Copied: 7MMH_ZJY_ligand.mol2
# Copied: 6YRV_PJ8_ligand.mol2
# Copied: 6YRV_PJ8_ligand.sdf
# Copied: 6VS3_R6V_ligand.sdf
# Copied: 6VS3_R6V_ligand.mol2
# Copied: 8DW5_FQ7_ligand.sdf
# Copied: 8DW5_FQ7_ligand.mol2
# Copied: 7AVI_S2Q_ligand.sdf
# Copied: 7AVI_S2Q_ligand.mol2
# Copied: 7RH3_59O_ligand.mol2
# Copied: 7RH3_59O_ligand.sdf
# Copied: 7WL4_JFU_ligand.mol2
# Copied: 7WL4_JFU_ligand.sdf
# Copied: 7CNQ_G8X_ligand.sdf
# Copied: 7CNQ_G8X_ligand.mol2
# Copied: 6YT6_PKE_ligand.sdf
# Copied: 6YT6_PKE_ligand.mol2
# Copied: 8A2D_KXY_ligand.sdf
# Copied: 8A2D_KXY_ligand.mol2
# Copied: 7N03_ZRP_ligand.sdf
# Copied: 7N03_ZRP_ligand.mol2
# Copied: 7TE8_P0T_ligand.sdf
# Copied: 7TE8_P0T_ligand.mol2
# Copied: 7WDT_NGS_ligand.sdf
# Copied: 7WDT_NGS_ligand.mol2
# Copied: 6M73_FNR_ligand.sdf
# Copied: 6M73_FNR_ligand.mol2
# Copied: 7LZD_YHY_ligand.sdf
# Copied: 7LZD_YHY_ligand.mol2
# Copied: 7TH4_FFO_ligand.mol2
# Copied: 7TH4_FFO_ligand.sdf
# Copied: 7P85_5ZG_ligand.mol2
# Copied: 7P85_5ZG_ligand.sdf
# Copied: 7YZU_DO7_ligand.mol2
# Copied: 7YZU_DO7_ligand.sdf
# Copied: 7UY4_SMI_ligand.mol2
# Copied: 7UY4_SMI_ligand.sdf
# Copied: 7B0E_C2E_ligand.mol2
# Copied: 7B0E_C2E_ligand.sdf
# Copied: 6VTA_AKN_ligand.mol2
# Copied: 6VTA_AKN_ligand.sdf
# Copied: 7PJQ_OWH_ligand.mol2
# Copied: 7PJQ_OWH_ligand.sdf
# Copied: 7ZXV_45D_ligand.sdf
# Copied: 7ZXV_45D_ligand.mol2
# Copied: 7NPL_UKZ_ligand.sdf
# Copied: 7NPL_UKZ_ligand.mol2
# All SDF/MOL2 files have been copied to /mnt/data/posebusters_fabind/gt_mol_files
# Copied: 6TW5_9M2.pdb
# Copied: 8E77_ULP.pdb
# Copied: 7U3J_L6U.pdb
# Copied: 7M3H_YPV.pdb
# Copied: 8AEM_LVF.pdb
# Copied: 7JNB_A2G.pdb
# Copied: 7AKL_RK5.pdb
# Copied: 7OKF_VH5.pdb
# Copied: 7BCP_GCO.pdb
# Copied: 7WY1_D0L.pdb
# Copied: 7Q27_8KC.pdb
# Copied: 8AIE_M7L.pdb
# Copied: 6YYO_Q1K.pdb
# Copied: 7NB4_U6Q.pdb
# Copied: 7NGW_UAW.pdb
# Copied: 8H0M_2EH.pdb
# Copied: 8EX2_Q2Q.pdb
# Copied: 7UXS_OJC.pdb
# Copied: 7MGY_ZD1.pdb
# Copied: 8DKO_TFB.pdb
# Copied: 7CL8_TES.pdb
# Copied: 7T0U_E3I.pdb
# Copied: 7PIH_7QW.pdb
# Copied: 7ELT_TYM.pdb
# Copied: 7ZU2_DHT.pdb
# Copied: 7ZOC_T8E.pdb
# Copied: 7N4N_0BK.pdb
# Copied: 7SZA_DUI.pdb
# Copied: 7W06_ITN.pdb
# Copied: 7UMW_NAD.pdb
