# %%
import os
import csv
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from networkx.algorithms import isomorphism
import networkx as nx

# change your path here
root_dir = './dynamicbind'
output_csv = './dynamicbind/dynamicbind_rmsd.csv'

def read_sdf(file_path):
    mol = Chem.SDMolSupplier(file_path)[0]
    return mol

def mol_to_graph(mol):
    G = nx.Graph()
    
    for atom in mol.GetAtoms():
        G.add_node(atom.GetIdx(), atom_type=atom.GetSymbol())
    
    for bond in mol.GetBonds():
        G.add_edge(bond.GetBeginAtomIdx(), bond.GetEndAtomIdx())
    
    return G

def calculate_rmsd(mol1, mol2, atom_map):
    coords1 = mol1.GetConformer().GetPositions()
    coords2 = mol2.GetConformer().GetPositions()
    
    mapped_coords1 = np.array([coords1[i] for i in atom_map.keys()])
    mapped_coords2 = np.array([coords2[i] for i in atom_map.values()])
    
    diff = mapped_coords1 - mapped_coords2
    #print(coords1, coords2), print(mapped_coords1, mapped_coords2), print(diff)
    return np.sqrt(np.mean(np.sum(diff**2, axis=1)))

def calculate_rmsd_without_alignment(sdf_file1, sdf_file2):
    mol1 = read_sdf(sdf_file1)
    mol2 = read_sdf(sdf_file2)
    
    graph1 = mol_to_graph(mol1)
    if mol2 is None:
        return None
    else:
        graph2 = mol_to_graph(mol2)
    
    nm = isomorphism.GraphMatcher(graph1, graph2, 
                                  node_match=lambda n1, n2: n1['atom_type'] == n2['atom_type'])
    
    if nm.is_isomorphic():
        atom_map = nm.mapping
        rmsd = calculate_rmsd(mol1, mol2, atom_map)
        return rmsd
    else:
        return None

def process_sdfs(root_dir,output_csv):
    if os.path.exists(output_csv):
        os.remove(output_csv)
    # Get all the subdir name in the rootdir
    subdir_list = os.listdir(root_dir)
    with open(output_csv, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['pdb_id', 'rmsd'])
    for pdb_id in subdir_list:
        # Get the ligand.sdf file path
        sdf_file1 = f'{root_dir}/{pdb_id}/{pdb_id}_docked_ligand.sdf'
        sdf_file2 = f'/mnt/data/posebusters/posebusters_benchmark_set/{pdb_id}/{pdb_id}_ligand.sdf'
        rmsd = calculate_rmsd_without_alignment(sdf_file1, sdf_file2)
        if rmsd is not None:
            print(f"{pdb_id} RMSD without alignment: {rmsd:.4f}")
        else:
            print(f"{pdb_id} The molecules are not isomorphic.")   
        with open(output_csv, 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([pdb_id, rmsd])

process_sdfs(root_dir,output_csv)
# Out:
# 8GFD_ZHR RMSD without alignment: 3.2615
# 7SIU_9ID RMSD without alignment: 47.2155
# 7CUO_PHB RMSD without alignment: 4.6656
# 7NR6_UO8 RMSD without alignment: 2.6685
# 7UAW_MF6 RMSD without alignment: 22.2183
# 7JG0_GAR RMSD without alignment: 9.9615
# 8H0M_2EH RMSD without alignment: 5.2954
# 7KLX_WOV RMSD without alignment: 16.6474
# 7KQU_YOF RMSD without alignment: 29.2009
# 7Z7F_IF3 RMSD without alignment: 3.6126
# 8EAD_UY0 RMSD without alignment: 1.5367
# 7R59_I5F RMSD without alignment: 1.5164
# 7ZXZ_K9R RMSD without alignment: 18.7850
# 8BOM_QU6 RMSD without alignment: 3.7167
# 7JR8_VH7 RMSD without alignment: 25.9528
# 7PGX_FMN RMSD without alignment: 4.7687
# 8CI0_8EL RMSD without alignment: 97.3319
# 8BN6_R53 RMSD without alignment: 1.3924
# 7R9N_F97 RMSD without alignment: 0.9745
# 7WCF_ACP RMSD without alignment: 2.4535
# 7ODX_DGP RMSD without alignment: 2.3278
# 7EN7_J79 RMSD without alignment: 4.5594
# 7UMV_NUU RMSD without alignment: 16.3391
# 7XI7_4RI RMSD without alignment: 1.3583
# 7RUI_7QZ RMSD without alignment: 2.0653
# 7WUY_76N RMSD without alignment: 32.3802
# 7L81_UD4 RMSD without alignment: 13.0686
# 7RKW_5TV RMSD without alignment: 16.2338
# 7LT0_ONJ RMSD without alignment: 3.0780
# 7T3E_SLB RMSD without alignment: 2.0632
# 7QE4_NGA RMSD without alignment: 106.9835
# 7NLK_UHK RMSD without alignment: 1.9747
# 7KFO_IAC RMSD without alignment: 5.2643
# 7Q27_8KC RMSD without alignment: 1.5894
# 8G0V_YHT RMSD without alignment: 3.0733
# 8D5D_5DK RMSD without alignment: 4.7767
# 7NP6_UK8 RMSD without alignment: 14.5926
# 7L7C_XQ1 RMSD without alignment: 2.8699
# 7FT9_4MB RMSD without alignment: 47.7988
# 6ZT2_QPK RMSD without alignment: 2.6043
# 7P5T_5YG RMSD without alignment: 13.0747
# 7MAE_XUS RMSD without alignment: 3.4175
# 7WN5_JGL RMSD without alignment: 38.7272
# 8AIE_M7L RMSD without alignment: 28.7865
# 7E2S_BLA RMSD without alignment: 8.6125
# 7E4L_MDN RMSD without alignment: 38.1184
# 7MRH_ZMJ RMSD without alignment: 4.4525
# 7JGW_V9S RMSD without alignment: 15.7679
# 7WPW_F15 RMSD without alignment: 1.0826
# 7ZL5_IWE RMSD without alignment: 1.1802
# 8CSD_C5P RMSD without alignment: 51.5040
# 7U0U_FK5 RMSD without alignment: 9.2122
# 7RNI_60I RMSD without alignment: 4.6460
# 6TW5_9M2 RMSD without alignment: 67.7737
# 6W59_SZD RMSD without alignment: 31.4785
# 7WJB_BGC RMSD without alignment: 1.6297
# 8D39_QDB RMSD without alignment: 5.3511
# 8ACL_LQL RMSD without alignment: 5.1158
# 8C3N_ADP RMSD without alignment: 23.5454
# 7Q19_DSM RMSD without alignment: 5.0552
# 7C0U_FGO RMSD without alignment: 3.6453
# 8AQL_PLG RMSD without alignment: 27.9034
# 7RWO_7WN RMSD without alignment: 2.6767
# 7UJF_R3V RMSD without alignment: 0.9962
# 7SDD_4IP RMSD without alignment: 5.1316
# 7MMH_ZJY RMSD without alignment: 8.1314
# 8DW5_FQ7 RMSD without alignment: 2.2570
# 7NU0_DCL RMSD without alignment: 2.4203
# 7F5D_EUO RMSD without alignment: 5.6538
# 7OP9_06K RMSD without alignment: 102.0910
# 7KZ9_XN7 RMSD without alignment: 50.4280
# 7W06_ITN RMSD without alignment: 4.7911
# 7XFA_D9J RMSD without alignment: 1.8281
# 7KB1_WBJ RMSD without alignment: 5.9682
# 7PIH_7QW RMSD without alignment: 2.5540
# 7R3D_APR RMSD without alignment: 41.9468
# 7MWN_WI5 RMSD without alignment: 4.5386
# 8A1H_DLZ RMSD without alignment: 24.7365
# 7UEY_N0R RMSD without alignment: 21.0477
# 6WTN_RXT RMSD without alignment: 3.1623
# 8DP2_UMA RMSD without alignment: 5.4448
# 7BA0_T5H RMSD without alignment: 2.9260
# 6YYO_Q1K RMSD without alignment: 8.8088
# 7ZU2_DHT RMSD without alignment: 0.4650
# 7ELT_TYM RMSD without alignment: 3.8558
# 7UJ5_DGL RMSD without alignment: 19.5841
# 7V3N_AKG RMSD without alignment: 3.4551
# 7B0E_C2E RMSD without alignment: 20.1326
# 6Y7L_QMG RMSD without alignment: 4.2487
# 7SSM_B7L RMSD without alignment: 7.4227
# 8DZT_G4P RMSD without alignment: 2.4379
# 7U3J_L6U RMSD without alignment: 4.5748
# 7QF4_RBF RMSD without alignment: 4.5414
# 6ZAE_ACV RMSD without alignment: 2.3179
# 7ED2_A3P RMSD without alignment: 16.0443
# 7T3F_EM0 RMSD without alignment: 1.9284
# 7A9H_TPP RMSD without alignment: 7.1593
# 7ROR_69X RMSD without alignment: 10.3168
# 7OLT_58J RMSD without alignment: 6.9862
# 7NXO_UU8 RMSD without alignment: 34.1540
# 7UP3_NZ0 RMSD without alignment: 1.9934
# 7QPP_VDX RMSD without alignment: 1.7551
# 8A2D_KXY RMSD without alignment: 17.2693
# 6T88_MWQ RMSD without alignment: 5.0497
# 7C3U_AZG RMSD without alignment: 22.3528
# 7Q25_8J9 RMSD without alignment: 5.1724
# 7PRM_81I RMSD without alignment: 1.8184
# 7TXP_0FX RMSD without alignment: 2.1756
# 7S9H_7PP RMSD without alignment: 1.1787
# 7VJT_7IJ RMSD without alignment: 19.9908
# 7MGT_ZD4 RMSD without alignment: 12.6620
# 7UY4_SMI RMSD without alignment: 40.0301
# 7D5C_GV6 RMSD without alignment: 2.4507
# 7NF3_4LU RMSD without alignment: 6.1062
# 7RC3_SAH RMSD without alignment: 1.4672
# 8C5M_MTA RMSD without alignment: 1.3873
# 8E77_ULP RMSD without alignment: 11.1034
# 7T9O_GEI RMSD without alignment: 7.0161
# 7CL8_TES RMSD without alignment: 2.6875
# 8C5D_GTB RMSD without alignment: 26.3852
# 7REE_4LY RMSD without alignment: 3.4643
# 7LJN_GTP RMSD without alignment: 44.6515
# 8FV9_80J RMSD without alignment: 30.8548
# 8AEU_M0L RMSD without alignment: 1.6620
# 6XM9_V55 RMSD without alignment: 4.0508
# 7TSF_H4B RMSD without alignment: 12.1810
# 7F8T_FAD RMSD without alignment: 14.9115
# 7WUX_6OI RMSD without alignment: 6.1321
# 7LZD_YHY RMSD without alignment: 8.6067
# 7BHX_TO5 RMSD without alignment: 35.5772
# 7O0N_CDP RMSD without alignment: 11.1241
# 8AUH_L9I RMSD without alignment: 44.3720
# 7QFM_AY3 RMSD without alignment: 2.1073
# 7TUO_KL9 RMSD without alignment: 11.1877
# 7OFK_VCH RMSD without alignment: 1.9625
# 7RSV_7IQ RMSD without alignment: 0.7898
# 7X5N_5M5 RMSD without alignment: 35.8134
# 6Z5Z_BDF RMSD without alignment: 17.8367
# 7ZZW_KKW RMSD without alignment: 53.8740
# 7OMJ_GCP RMSD without alignment: 3.1626
# 6M73_FNR RMSD without alignment: 9.4158
# 7N4W_P4V RMSD without alignment: 8.3787
# 7EBG_J0L RMSD without alignment: 25.0794
# 7VBU_6I4 RMSD without alignment: 2.2893
# 7PL1_SFG RMSD without alignment: 1.2435
# 7N7B_T3F RMSD without alignment: 38.8989
# 7UAS_MBU RMSD without alignment: 56.9810
# 7NSW_HC4 RMSD without alignment: 39.4565
# 7VC5_9SF RMSD without alignment: 0.8414
# 7PUV_84Z RMSD without alignment: 46.1353
# 7VB8_STL RMSD without alignment: 6.8360
# 8FLN_Y7W RMSD without alignment: 2.1753
# 7XQZ_FPF RMSD without alignment: 9.8112
# 7Q2B_M6H RMSD without alignment: 4.3645
# 5SB2_1K2 RMSD without alignment: 1.1216
# 7JY3_VUD RMSD without alignment: 31.8586
# 7L03_F9F RMSD without alignment: 1.7808
# 8G6P_API RMSD without alignment: 12.3036
# 7AN5_RDH RMSD without alignment: 40.2507
# 7UJ4_OQ4 RMSD without alignment: 33.7646
# 7JMV_4NC RMSD without alignment: 3.1108
# 7N7H_CTP RMSD without alignment: 9.3927
# 6ZR8_QOZ RMSD without alignment: 2.1132
# 7BNH_BEZ RMSD without alignment: 2.3596
# 7LCU_XTA RMSD without alignment: 11.0565
# 7RH8_UTP RMSD without alignment: 29.7193
# 7UTW_NAI RMSD without alignment: 40.6037
# 6Z1C_7EY RMSD without alignment: 4.6981
# 6TW7_NZB RMSD without alignment: 5.4867
# 7T0D_FPP RMSD without alignment: 5.9672
# 7L6D_BMF RMSD without alignment: 3.5720
# 7TM6_GPJ RMSD without alignment: 1.6673
# 8G43_ZU6 RMSD without alignment: 2.0057
# 8AP0_PRP RMSD without alignment: 5.5998
# 7ZDY_6MJ RMSD without alignment: 48.0822
# 7LB3_XXS RMSD without alignment: 5.6232
# 6XCT_478 RMSD without alignment: 8.6347
# 7NGW_UAW RMSD without alignment: 2.3547
# 6YR2_T1C RMSD without alignment: 6.4943
# 7OU8_1XI RMSD without alignment: 1.2414
# 7NB4_U6Q RMSD without alignment: 6.6943
# 7KRU_ATP RMSD without alignment: 27.1608
# 7W6F_8I6 RMSD without alignment: 12.1450
# 8D19_GSH RMSD without alignment: 39.0421
# 7D0P_1VU RMSD without alignment: 21.6515
# 7MEU_MGP RMSD without alignment: 1.6333
# 7FHA_ADX RMSD without alignment: 2.8980
# 7UMW_NAD RMSD without alignment: 35.2128
# 7AVI_S2Q RMSD without alignment: 84.6537
# 7A1P_QW2 RMSD without alignment: 1.5888
# 6XBO_5MC RMSD without alignment: 4.1351
# 7BJ6_TVK RMSD without alignment: 1.8349
# 6YT6_PKE RMSD without alignment: 45.6012
# 7BLG_GAL RMSD without alignment: 3.7839
# 7SGV_L30 RMSD without alignment: 30.0322
# 7YZU_DO7 RMSD without alignment: 4.2411
# 7BCP_GCO RMSD without alignment: 2.9733
# 7QK0_EBL RMSD without alignment: 24.3702
# 8F8E_XJI RMSD without alignment: 48.2314
# 7MYU_ZR7 RMSD without alignment: 49.2628
# 7UXS_OJC RMSD without alignment: 17.8201
# 7RWS_4UR RMSD without alignment: 9.2277
# 7MY1_IPE RMSD without alignment: 4.0841
# 7XPO_UPG RMSD without alignment: 15.8077
# 7CIJ_G0C RMSD without alignment: 27.2412
# 7ROU_66I RMSD without alignment: 10.6305
# 7P4J_5JK RMSD without alignment: 8.6412
# 7QGP_DJ8 RMSD without alignment: 2.4753
# 7MOI_HPS RMSD without alignment: 3.0504
# 6X8D_ARA RMSD without alignment: 3.5813
# 7SZA_DUI RMSD without alignment: 51.1268
# 7SED_8VD RMSD without alignment: 10.7530
# 5SAK_ZRY RMSD without alignment: 6.2604
# 7C6P_SQH RMSD without alignment: 1.2415
# 7LOU_IFM RMSD without alignment: 8.6447
# 7ZYS_KNR RMSD without alignment: 5.8136
# 7P4C_5OV RMSD without alignment: 1.2246
# 7PK0_BYC RMSD without alignment: 11.2411
# 7QTA_URI RMSD without alignment: 7.5979
# 6VTA_AKN RMSD without alignment: 8.1417
# 7PA4_C RMSD without alignment: 23.9138
# 6YSP_PAL RMSD without alignment: 33.0335
# 8EXL_799 RMSD without alignment: 1.5575
# 7L00_XCJ RMSD without alignment: 7.2652
# 7WY1_D0L RMSD without alignment: 12.2043
# 7N03_ZRP RMSD without alignment: 2.4281
# 7XG5_PLP RMSD without alignment: 28.7235
# 7NTG_F6R RMSD without alignment: 3.3617
# 7ZF0_DHR RMSD without alignment: 2.5972
# 7T2I_E9F RMSD without alignment: 27.3074
# 7TYP_KUR RMSD without alignment: 26.1822
# 7Z2O_IAJ RMSD without alignment: 3.0964
# 6ZK5_IMH RMSD without alignment: 2.2210
# 7FB7_8NF RMSD without alignment: 49.1231
# 7V3S_5I9 RMSD without alignment: 0.9106
# 7P4V_DAT RMSD without alignment: 4.3905
# 7VKZ_NOJ RMSD without alignment: 0.3219
# 6M2B_EZO RMSD without alignment: 21.0470
# 7ZCC_OGA RMSD without alignment: 40.8942
# 7WQQ_5Z6 RMSD without alignment: 3.6722
# 8HO0_3ZI RMSD without alignment: 8.4032
# 7NFB_GEN RMSD without alignment: 29.6882
# 6XG5_TOP RMSD without alignment: 3.0021
# 8B8H_OJQ RMSD without alignment: 34.5282
# 7D8Q_GZF RMSD without alignment: 8.5229
# 7KC5_BJZ RMSD without alignment: 49.8882
# 7V14_ORU RMSD without alignment: 1.0355
# 7OPG_06N RMSD without alignment: 5.1070
# 7TXK_LW8 RMSD without alignment: 4.6593
# 7VQ9_ISY RMSD without alignment: 31.3985
# 7OZ9_NGK RMSD without alignment: 75.5029
# 7B94_ANP RMSD without alignment: 1.0986
# 7K0V_VQP RMSD without alignment: 0.8289
# 6ZCY_QF8 RMSD without alignment: 1.0857
# 7WKL_CAQ RMSD without alignment: 3.7724
# 7CD9_FVR RMSD without alignment: 14.6909
# 7N6F_0I1 RMSD without alignment: 8.3687
# 7QSW_CAP RMSD without alignment: 1.6706
# 7VYJ_CA0 RMSD without alignment: 8.9874
# 7T0U_E3I RMSD without alignment: 22.2348
# 6Z0R_Q4H RMSD without alignment: 12.4843
# 7Z1Q_NIO RMSD without alignment: 1.8520
# 8ERS_WQO RMSD without alignment: 42.7170
# 8DHG_T78 RMSD without alignment: 13.5085
# 7X9K_8OG RMSD without alignment: 8.1109
# 8HFN_XGC RMSD without alignment: 3.1891
# 7JUD_MMA RMSD without alignment: 33.3227
# 7OEO_V9Z RMSD without alignment: 2.6853
# 7ORW_7WA RMSD without alignment: 21.1409
# 6YJA_2BA RMSD without alignment: 7.5605
# 8SLG_G5A RMSD without alignment: 31.3578
# 7VWF_K55 RMSD without alignment: 3.6303
# 6ZXQ_IMO RMSD without alignment: 2.3468
# 8DKO_TFB RMSD without alignment: 4.2450
# 7LOE_Y84 RMSD without alignment: 1.3023
# 7ZOC_T8E RMSD without alignment: 1.5901
# 7QHG_T3B RMSD without alignment: 2.1167
# 7OMX_CNA RMSD without alignment: 10.6786
# 7KM8_WPD RMSD without alignment: 2.9481
# 7OFF_VCB RMSD without alignment: 4.7035
# 7O1T_5X8 RMSD without alignment: 6.8009
# 6ZX3_QRZ RMSD without alignment: 1.0899
# 7OKF_VH5 RMSD without alignment: 27.3208
# 7P2I_MFU RMSD without alignment: 17.7685
# 7TOM_5AD RMSD without alignment: 16.2008
# 8CNH_V6U RMSD without alignment: 4.4665
# 8AAU_LH0 RMSD without alignment: 4.3403
# 5SD5_HWI RMSD without alignment: 2.7504
# 7P1M_4IU RMSD without alignment: 47.6326
# 7EPV_FDA RMSD without alignment: 4.4450
# 7D9L_GSF RMSD without alignment: 2.2927
# 6YQV_8K2 RMSD without alignment: 1.8636
# 7T1D_E7K RMSD without alignment: 31.4032
# 6YQW_82I RMSD without alignment: 3.1849
# 7SCW_GSP RMSD without alignment: 1.2632
# 7RPZ_6IC RMSD without alignment: 17.3140
# 7ES1_UDP RMSD without alignment: 13.0827
# 6YRV_PJ8 RMSD without alignment: 10.2518
# 7NF0_BYN RMSD without alignment: 9.6973
# 7WDT_NGS RMSD without alignment: 3.0276
# 7TBU_S3P RMSD without alignment: 39.6134
# 7JNB_A2G RMSD without alignment: 1.9729
# 7ZZB_KGX RMSD without alignment: 7.0865
# 7NA4_1I9 RMSD without alignment: 5.6422
# 6XUM_30L RMSD without alignment: 2.9129
# 7ZXV_45D RMSD without alignment: 7.1823
# 7XEK_9YX RMSD without alignment: 3.6919
# 7NML_I7B RMSD without alignment: 42.3116
# 7PRI_7TI RMSD without alignment: 51.9311
# 7NPL_UKZ RMSD without alignment: 19.5667
# 6YMS_OZH RMSD without alignment: 10.1747
# 7TS6_KMI RMSD without alignment: 96.7102
# 7BJJ_TVW RMSD without alignment: 0.6714
# 7DIN_MPO RMSD without alignment: 7.2840
# 7ZTL_BCN RMSD without alignment: 14.3099
# 7ODY_DGI RMSD without alignment: 5.1447
# 7AFX_R9K RMSD without alignment: 5.1237
# 7LEV_0JO RMSD without alignment: 34.2543
# 7CTM_BDP RMSD without alignment: 6.2539
# 7DUA_HJ0 RMSD without alignment: 32.1294
# 7XBV_APC RMSD without alignment: 2.5619
# 8AY3_OE3 RMSD without alignment: 2.8924
# 7LZQ_YJV RMSD without alignment: 19.5579
# 7KP6_WTP RMSD without alignment: 48.0634
# 7SFO_98L RMSD without alignment: 30.1399
# 7N4N_0BK RMSD without alignment: 1.2033
# 7OLI_8HG RMSD without alignment: 39.6164
# 7MGY_ZD1 RMSD without alignment: 1.4013
# 7OSO_0V1 RMSD without alignment: 2.9910
# 6ZC3_JOR RMSD without alignment: 23.2763
# 7F51_BA7 RMSD without alignment: 3.4391
# 7MZS_GLA RMSD without alignment: 21.4901
# 7OKC_VFE RMSD without alignment: 9.1884
# 7S45_ACO RMSD without alignment: 25.9834
# 7LMO_NYO RMSD without alignment: 14.6345
# 7BLA_WCS RMSD without alignment: 8.5470
# 7UQ3_O2U RMSD without alignment: 2.4798
# 7L5F_XNG RMSD without alignment: 4.9312
# 6XAF_GDP RMSD without alignment: 36.5515
# 7DQL_4CL RMSD without alignment: 43.1259
# 6Z2C_Q5E RMSD without alignment: 43.6389
# 7DKT_GLF RMSD without alignment: 0.5154
# 7AKL_RK5 RMSD without alignment: 6.9850
# 7A9E_R4W RMSD without alignment: 19.6223
# 6Z4N_Q7B RMSD without alignment: 38.8054
# 8BRO_R7E RMSD without alignment: 16.0107
# 7NR8_UOE RMSD without alignment: 2.7279
# 7R7R_AWJ RMSD without alignment: 1.0195
# 7POM_7VZ RMSD without alignment: 2.1296
# 7K41_VUA RMSD without alignment: 6.9502
# 7ECR_SIN RMSD without alignment: 37.8040
# 7CNS_PMV RMSD without alignment: 5.0978
# 8CGC_LMR RMSD without alignment: 18.8993
# 7P2W_4QR RMSD without alignment: 3.6598
# 7M6K_YRJ RMSD without alignment: 37.4259
# 7XIJ_EJ3 RMSD without alignment: 2.7240
# 8AEM_LVF RMSD without alignment: 15.1500
# 7MS7_ZQ1 RMSD without alignment: 8.8117
# 7P85_5ZG RMSD without alignment: 28.5366
# 7M3H_YPV RMSD without alignment: 21.3087
# 6ZPB_3D1 RMSD without alignment: 7.4923
# 7TWC_CXS RMSD without alignment: 8.4426
# 7W05_GMP RMSD without alignment: 8.1941
# 8FO5_Y4U RMSD without alignment: 82.4224
# 7SUC_COM RMSD without alignment: 18.3570
# 7AS1_21G RMSD without alignment: 7.5546
# 7RZL_NPO RMSD without alignment: 2.2219
# 8BTI_RFO RMSD without alignment: 3.0240
# 7MSR_DCA RMSD without alignment: 16.6356
# 7XJN_NSD RMSD without alignment: 51.8213
# 6Z14_Q4Z RMSD without alignment: 1.9368
# 8FAV_4Y5 RMSD without alignment: 72.1916
# 7PT3_3KK RMSD without alignment: 15.3623
# 7SNE_9XR RMSD without alignment: 57.3972
# 6VS3_R6V RMSD without alignment: 3.1015
# 7ULC_56B RMSD without alignment: 5.6490
# 7C8Q_DSG RMSD without alignment: 35.8968
# 5SIS_JSM RMSD without alignment: 1.6099
# 7AMC_73B RMSD without alignment: 1.5399
# 5S8I_2LY RMSD without alignment: 5.0312
# 8EAB_VN2 RMSD without alignment: 9.9097
# 8FLV_ZB9 RMSD without alignment: 1.1376
# 7V43_C4O RMSD without alignment: 2.6820
# 7UF2_5SP RMSD without alignment: 1.1513
# 7MWU_ZPM RMSD without alignment: 3.5224
# 7BKA_4JC RMSD without alignment: 20.9049
# 7OZC_G6S RMSD without alignment: 5.5225
# 7PJQ_OWH RMSD without alignment: 3.3739
# 7BMI_U4B RMSD without alignment: 5.5664
# 8EYE_X4I RMSD without alignment: 2.1028
# 7UYB_OK0 RMSD without alignment: 1.7904
# 7OCB_V88 RMSD without alignment: 6.6270
# 7NUT_GLP RMSD without alignment: 3.9523
# 7TH4_FFO RMSD without alignment: 51.8693
# 7JXX_VP7 RMSD without alignment: 7.2843
# 7AA0_R6B RMSD without alignment: 42.2266
# 7MFP_Z7P RMSD without alignment: 23.5713
# 8BPL_CP RMSD without alignment: 1.4790
# 7JHQ_VAJ RMSD without alignment: 38.9809
# 7THI_PGA RMSD without alignment: 46.0287
# 7USH_82V RMSD without alignment: 1.7297
# 8DSC_NCA RMSD without alignment: 4.5155
# 7P1F_KFN RMSD without alignment: 4.4829
# 8C7Y_TXV RMSD without alignment: 27.0864
# 7ZHP_IQY RMSD without alignment: 8.3955
# 7BTT_F8R RMSD without alignment: 1.1837
# 8EX2_Q2Q RMSD without alignment: 6.4466
# 7R6J_2I7 RMSD without alignment: 4.4894
# 8AJX_FUM RMSD without alignment: 5.7819
# 6YDY_K73 RMSD without alignment: 1.0473
# 7M41_YQG RMSD without alignment: 19.5859
# 7RH3_59O RMSD without alignment: 2.5859
# 7Q5I_I0F RMSD without alignment: 1.2986
# 7V8Z_5YH RMSD without alignment: 8.9491

# %%
data = pd.read_csv(output_csv)

# rmsd < 2
valid_rmsd = data[data['rmsd'] != -1]
rmsd_less_than_2 = valid_rmsd[valid_rmsd['rmsd'] < 2]
rmsd_less_than_2_ratio = len(rmsd_less_than_2) / len(data)

# success rate
total_entries = len(data)
successful_entries = len(rmsd_less_than_2)
success_rate = successful_entries / total_entries

print(f"rmsd < 2: {rmsd_less_than_2_ratio:.2%}")
print(f"success rate: {success_rate:.2%}")
# Out:
# rmsd < 2: 15.70%
# success rate: 15.70%
